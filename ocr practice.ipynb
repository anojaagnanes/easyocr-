# %%
import easyocr

# %%
reader = easyocr.Reader(['en'],gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
import PIL

# %%
from PIL import ImageDraw
im = PIL.Image.open("text.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=578x851 at 0x7F74A5A76450>

# %%
bounds = reader.readtext('text.jpg')
bounds
# Out:
# [([[30, 54], [168, 54], [168, 82], [30, 82]],
#   'The Ihree Lltlle Pigs',
#   0.017851848155260086),
#  ([[29, 89], [515, 89], [515, 127], [29, 127]],
#   'wolfsaid thar he also wanted to have some ofthe',
#   0.026857316493988037),
#  ([[27, 117], [489, 117], [489, 155], [27, 155]],
#   'cabbage leaves for his dinner from her house.',
#   0.27449387311935425),
#  ([[56, 153], [517, 153], [517, 195], [56, 195]],
#   'Whitey cried, "Please do not cat the cabbages.',
#   0.028894267976284027),
#  ([[89, 185], [523, 185], [523, 221], [89, 221]],
#   'are the walls of my house and if you cat',
#   0.009696570225059986),
#  ([[29, 196], [86, 196], [86, 224], [29, 224]], 'They', 0.972184956073761),
#  ([[95, 212], [525, 212], [525, 249], [95, 249]],
#   'there would be a hole in my house andI',
#   0.0028316962998360395),
#  ([[28, 228], [94, 228], [94, 252], [28, 252]], 'them,', 0.3064567744731903),
#  ([[28, 243], [529, 243], [529, 281], [28, 281]],
#   'would have to bear the wind and rain. Iam sure',
#   0.022290321066975594),
#  ([[73, 269], [531, 269], [531, 307], [73, 307]],
#   'are not a friend but the wicked fox. Pleasc go',
#   0.032021619379520416),
#  ([[28, 288], [74, 288], [74, 314], [28, 314]], 'you', 0.81363844871521),
#  ([[31, 317], [91, 317], [91, 337], [31, 337]], 'awav:', 0.24153554439544678),
#  ([[60, 341], [537, 341], [537, 383], [60, 383]],
#   'Whitey was very afraid and repented for her',
#   0.08318913727998734),
#  ([[240, 372], [540, 372], [540, 404], [240, 404]],
#   'a solid material instead of',
#   0.23875001072883606),
#  ([[108, 378], [232, 378], [232, 408], [108, 408]],
#   'If she had',
#   0.27431797981262207),
#  ([[27.41000317999046, 391.45600508798475],
#    [99.65829463842645, 383.6095074199],
#    [101.58999682000955, 412.54399491201525],
#    [29.341705361573542, 420.3904925801]],
#   'greed.',
#   0.9593396782875061),
#  ([[131, 401], [543, 401], [543, 439], [131, 439]],
#   'that made her house, she would have',
#   0.0431053601205349),
#  ([[29, 414], [130, 414], [130, 447], [29, 447]],
#   'cabbages',
#   0.9477522373199463),
#  ([[30, 444], [146, 444], [146, 474], [30, 474]],
#   'been safer.',
#   0.3694206178188324),
#  ([[448, 475], [550, 475], [550, 515], [448, 515]],
#   'scrapped',
#   0.8823803663253784),
#  ([[370, 480], [450, 480], [450, 506], [370, 506]],
#   'the fox',
#   0.7048948407173157),
#  ([[59, 482], [369, 482], [369, 519], [59, 519]],
#   'However, it was too late, as',
#   0.15737386047840118),
#  ([[29, 511], [433, 511], [433, 553], [29, 553]],
#   'in her house and took her to his den.',
#   0.1710909605026245),
#  ([[59, 555], [557, 555], [557, 599], [59, 599]],
#   "The next day, the fox reached Blacky's house",
#   0.019788270816206932),
#  ([[122, 587], [557, 587], [557, 629], [122, 629]],
#   'that it was made ofbricks and the door',
#   0.14516083896160126),
#  ([[30, 606], [124, 606], [124, 632], [30, 632]],
#   'and saw',
#   0.6703268885612488),
#  ([[304, 622], [560, 622], [560, 654], [304, 654]],
#   'He said, Pleasc accept',
#   0.03874616324901581),
#  ([[78, 625], [299, 625], [299, 665], [78, 665]],
#   'bolted from inside.',
#   0.4299294352531433),
#  ([[30, 642], [76, 642], [76, 666], [30, 666]], 'was', 0.7927054762840271),
#  ([[243, 654], [439, 654], [439, 693], [243, 693]],
#   'from your friend.',
#   0.25164368748664856),
#  ([[191.7811992150991, 668.6717988226486],
#    [242.6089676586017, 654.9679565048683],
#    [251.2188007849009, 690.3282011773514],
#    [200.3910323413983, 704.0320434951317]],
#   'gifi',
#   0.5588667988777161),
#  ([[26, 669], [179, 669], [179, 705], [26, 705]],
#   'these eggs as',
#   0.42375367879867554),
#  ([[56, 700], [568, 700], [568, 752], [56, 752]],
#   '"No, no, Master Fox. Iwill nor open my door',
#   0.00821663998067379),
#  ([[26, 738], [456, 738], [456, 790], [26, 790]],
#   'for you. Iknow your cunning wishes.',
#   0.06953783333301544)]

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=578x851 at 0x7F74A5A76450>

# %%
len(bounds)
# Out:
# 34

# %%
for i in bounds:
    print(i[1])
# Out:
# The Ihree Lltlle Pigs
# wolfsaid thar he also wanted to have some ofthe
# cabbage leaves for his dinner from her house.
# Whitey cried, "Please do not cat the cabbages.
# are the walls of my house and if you cat
# They
# there would be a hole in my house andI
# them,
# would have to bear the wind and rain. Iam sure
# are not a friend but the wicked fox. Pleasc go
# you
# awav:
# Whitey was very afraid and repented for her
# a solid material instead of
# If she had
# greed.
# that made her house, she would have
# cabbages
# been safer.
# scrapped
# the fox
# However, it was too late, as
# in her house and took her to his den.
# The next day, the fox reached Blacky's house
# that it was made ofbricks and the door
# and saw
# He said, Pleasc accept
# bolted from inside.
# was
# from your friend.
# gifi
# these eggs as
# "No, no, Master Fox. Iwill nor open my door
# for you. Iknow your cunning wishes.
